# %%
# !pip install -r requirements.txt

# %% [markdown]
# ### 1.Import Dependencies

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. Basic Processing

# %%
df = pd.read_csv('Week01/data/processed/CEHHbInToW_FeautureEncoding_Applied.csv')
df.head(5)
# Out:
#      Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0  42.00       2       0.00              1          1               1
# 1  41.00       1   83807.86              1          0               1
# 2  42.00       8  159660.80              3          1               0
# 3  38.91       1       0.00              2          0               0
# 4  43.00       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  CreditScoreBins  Geography_France  \
# 0        101348.88       1              NaN              True
# 1        112542.58       0              NaN             False
# 2        113931.57       1              NaN              True
# 3         93826.63       0              NaN              True
# 4         79084.10       0              NaN             False
#
#    Geography_Germany  Geography_Spain  Gender_Female  Gender_Male
# 0              False            False           True        False
# ...
